# %%
from paddleocr import PaddleOCR

# ocr = PaddleOCR(
#     use_doc_orientation_classify=False,
#     use_doc_unwarping=False,
#     use_textline_orientation=False,
# )  # text detection + text recognition
# ocr = PaddleOCR(
#     use_doc_orientation_classify=True, 
#     use_doc_unwarping=True
# )  # text image preprocessing + text detection + textline orientation classification + text recognition
ocr = PaddleOCR(use_doc_orientation_classify=False, use_doc_unwarping=False) # text detection + textline orientation classification + text recognition
# ocr = PaddleOCR(
#     text_detection_model_name="PP-OCRv5_mobile_det",
#     text_recognition_model_name="PP-OCRv5_mobile_rec",
#     use_doc_orientation_classify=True,
#     use_doc_unwarping=True) # Switch to PP-OCRv5_mobile models
result = ocr.predict("../examples/test_image.png")
for res in result:
    res.print()
    res.save_to_img("output")
    res.save_to_json("output")
# Out:
# Creating model: ('PP-LCNet_x1_0_doc_ori', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `C:\Users\WiZ\.paddlex\official_models\PP-LCNet_x1_0_doc_ori`.
# Creating model: ('UVDoc', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `C:\Users\WiZ\.paddlex\official_models\UVDoc`.
# Creating model: ('PP-LCNet_x1_0_textline_ori', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `C:\Users\WiZ\.paddlex\official_models\PP-LCNet_x1_0_textline_ori`.
# Creating model: ('PP-OCRv5_server_det', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `C:\Users\WiZ\.paddlex\official_models\PP-OCRv5_server_det`.
# Creating model: ('PP-OCRv5_server_rec', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `C:\Users\WiZ\.paddlex\official_models\PP-OCRv5_server_rec`.
# {'res': {'input_path': '../examples/test_image.png', 'page_index': None, 'model_settings': {'use_doc_preprocessor': True, 'use_textline_orientation': True}, 'doc_preprocessor_res': {'input_path': None, 'page_index': None, 'model_settings': {'use_doc_orientation_classify': True, 'use_doc_unwarping': True}, 'angle': 0}, 'dt_polys': array([[[  46,    2],
#         ...,
#         [  45,   42]],
#
#        ...,
#
#        [[1058, 2302],
#         ...,
#         [1058, 2333]]], shape=(415, 4, 2), dtype=int16), 'text_det_params': {'limit_side_len': 64, 'limit_type': 'min', 'thresh': 0.3, 'max_side_limit': 4000, 'box_thresh': 0.6, 'unclip_ratio': 1.5}, 'text_type': 'general', 'textline_orientation_angles': array([0, ..., 0], shape=(415,)), 'text_rec_score_thresh': 0.0, 'return_word_box': False, 'rec_texts': ['VIDA SRL UniperSONale', 'INAIL', 'BORGO RINASCIMENTO 2', '31039 RIESE PIO X', 'DEL 18/01/10', 'SEDE', 'E10/06/25', 'TV', 'N.Autor. 70517', '04696000266', 'P.IVA', '04696000266', 'Tel', '0314015', '16300', '13:09', 'C.FISCALE', '0423 040022', 'MATRICOLA INPS', 'POSIZIONE - VOCI INAIL', '722', 'CASSA', 'FILIALE', 'AZIENDA', 'DIPENDENT', '8411325077', 'REPARTO', 'CENTRO CONTABILE', 'CENTRODICOSTO', 'TURNISTA', 'QUAL./SOTTOQUAL.', '2219925262 100,00', 'EDILE', '2', '04/01', '656', '3', 'SINDAC.', 'TABELLA', '4', 'ENPALS', 'CODICE FISCALE', 'MATR.', 'MATR.', 'BNKYSF98D12F443T', 'MATRICOLA', 'COGNOME NOME', 'CODICE', 'BEN KHALIFA YOUSSEF', 'QUALIFICA E LIVELLO', 'CONTRATTO', 'TIPO RAPPORTO', '% PART-TIME', 'MANSIONE', '113', 'SESSO', 'LUOGO DI NASCITA', 'DATA DI NASCITA', 'NAZION.', 'APPRENDIST C3', 'P.T.', '70,00', 'APPRENDISTA', 'M', 'MONTEBELLUNA', 'TV', '12/04/1998', 'LUOGO DI RESIDENZA', 'PROVINCIA', "ANZIANITA'", 'STATUS', 'VIALE DELLA STAZIONE 18 INT.2', 'TELEFONO', 'LAVORO', '31044 MONTEBELLUNA', 'TV', '02.02', '00', 'TV', 'DATA ASSUNZIONE', "DATA ANZIANITA'", 'AZIENDALE', 'SCATTI', 'DATA SCADENZA', 'DATA SCADENZA', 'DATA SCADENZA', 'DATA VISITA MEDICA', 'DATA INIZIO', 'DATA FINE', 'DATA CESSAZIONE', '01/04/2023', 'NUMERO', 'DATA PROSSIMO', 'CONTRIBUTIVA', 'PERM. DI SOGGIORNO', 'TEMPO DETERMINATO', 'SOSPENSIONE', 'SOSPENSIONE', '01/12/2026', '30/09/2025', 'PAGA BASE', '2.024,03', 'Data', 'RETRIBUZIONE TOTALE', '2.024,03', 'GG.', 'ORD.', 'STRAOR.', 'ALTRE', 'RATEI 13ma', 'RATEI 14ma', 'RATEIPREMIC', 'ORE LAVORATE', 'GG. LAVORATI', 'ORE LAVORABILI', 'TEMPO MINIMALE', 'TEMPO T.F.R.', 'GIORNI INPS', 'SETTIMANE', 'TOTALI', '1 2 3', '4', '5', '6', '1', '19,00', '128,00', '128', '121,10', '26', '5X₁X₁X₁X₁X', '3,50', 'F', '108,00', '2', 'DESCRIZIONE', 'TEMPO', 'VALORE UNITARIO', 'COMPETENZE/', 'R', 'CODICE', 'ELEMENTO NEUTRO', 'TRATTENUTE', 'S', '3', 'Retribuzione ordinaria', '121,10', '11,69959', '1.416,82', '1.0001', '20,00', '11,69959', '233,99', 'D', '4', '1.0012', 'Ore non lavorate', '12,00', '11,69959', '140,40', '5', '4,00', '1.1221', 'R.O.L.goduti', '8,00', '11,69959', '93,60', '6', '4,00', '1.1251', "Festivita' godute", '7', '4,00', '1.6110', 'F.do MetaSalute c/az', '13,00', '8', '8,00', 'Ticket Restaurant elettronico', '95,00', '19,00', '5,00000', '1.0879', '6', '8,00', '2.5960', 'Retribuz. Teorica Emens', '1.416,82', '343,60000', '70,48', 'S10', '2.5977', 'Bonus integrativo 2025', '151,00', '17.303,44', '16,28-', 'D11', '2.5994', 'Addizion.regionale anno prec.', '21', '8,19-', '12', '4,00', '2.5995', 'Addizion.comunale anno prec.', 'F443', '3,53-', '13', '4,00', '2.5998', 'Acconto addizionale comunale', 'F443', '14', '4,00', '2.6082', 'Reddito teorico complessivo', '17.303,44', '15', '8,00', '16', '8,00', 'S17', 'D18', '19', 'R', '20', '4,00', '21', '4,00', '22', '8,00', '23', '8,00', '$24', '25', '26', '4,00', '27', '4,00', 'PAGAMENTO', '28', '4,00', 'IMPONIBILE', 'IMPON.', 'IMPON.', 'IMPON.', 'IMPON.', 'IMPONIBILE INAIL', 'ASSEGNI NUCLEO FAMILIARE', 'PREVIDENZIALE', 'GG.', 'IMPORTO', '29', '8,00', '1.417,00', '3 0', '8,00', 'RITEN.', 'RITEN.', 'RITEN.', 'RITEN.', 'RITEN.', 'RITEN.', 'TOTALE RITENUTE SOCIALI', '31', '87,00', '87,00', 'REDDITO FAMILIARE', 'IMPONIBILE FISCALE', 'IRPEF LORDA', 'DETRAZIONI LAVORO', 'DETRAZIONI CONIUGE', 'DETRAZIONI FIGLI', 'DETR, ALTRE PERSONE', 'DETRAZIONI ONERI', 'DEBITO/CREDITO IRPEF', 'NUC.TABELLA', 'IMPORTO', 'DIPENDENTE', 'GG.', 'IMPORTO', 'IND.', 'IMPORTO', 'N.', 'IMPORTO', 'N.', 'IMPORTO', '1.329,83', '305,86', '31', '245,50', '60,36', 'IMPONIBILE FISCALE ANNUALE', 'IRPEF LORDA ANNUALE', 'PROGRESSIVO DETRAZIONI', 'PROGRESSIVO IRPE ...
#         ...,
#         [  45,   42]],
#
#        ...,
#
#        [[1058, 2302],
#         ...,
#         [1058, 2333]]], shape=(415, 4, 2), dtype=int16), 'rec_boxes': array([[  45, ...,   49],
#        ...,
#        [1058, ..., 2333]], shape=(415, 4), dtype=int16)}}
